# %% [markdown]
# # Possible ML transformations (data pre-processing) for an Hive game dataset
#
# ## Main aspects of this Python Notebook:
# 1. Importing data from a csv containing info on a single match
# 2. Classifying the features in different categories:
#     - color_player columns ('number_of_turn', 'last_move_played_by', 'current_player_turn', 'result') -> assume values 'White' or 'Black'
#     - moves columns -> the one which indicates the possible moves for every piece
#     - neighbor columns -> the one which indicates the neighbor in every direction for every piece
# 3. Replacing all the NaN values with the value 0
# 4. Scaling the 'number_of_turn' feature
# 5. Encoding the categorical features related to the neighbor columns into numerical features
# 6. Encoding the categorical features related to the color_player columns into numerical features

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## 1. Importing Data
# Let's import the data from a csv containing the information of a single match played Random vs Random

# %%
# folder = '../data/'
# # Cycling in the folder data
# import os
# for file in os.listdir(folder):
#     url = folder + file
#     df = pd.read_csv(url)


url = '../data/match_1737734701_results.csv'
df = pd.read_csv(url)
df.shape
# Out:
# (8663, 202)

# %%
df.head()
# Out:
#    number_of_turn last_move_played_by current_player_turn  wQ_moves  \
# 0               1               White               Black         0
# 1               2               Black               White         0
# 2               3               White               Black         2
# 3               4               Black               White         2
# 4               5               White               Black         2
#
#    wS1_moves  wB1_moves  wG1_moves  wA1_moves  wS2_moves  wB2_moves  ...  \
# 0          0          0          0          0          0          0  ...
# 1          0          3          0          0          0          0  ...
# 2          0          4          0          0          0          0  ...
# 3          0          4          0          0          0          0  ...
# 4          0          3          0          0          0          3  ...
#
#    bG3_ABOVE_neighbor  bA3_RIGHT_neighbor  bA3_UP_RIGHT_neighbor  \
# 0                 NaN                 NaN                    NaN
# 1                 NaN                 NaN                    NaN
# 2                 NaN                 NaN                    NaN
# 3                 NaN                 NaN                    NaN
# 4                 NaN                 NaN                    NaN
#
#    bA3_UP_LEFT_neighbor  bA3_LEFT_neighbor  bA3_DOWN_LEFT_neighbor  \
# 0                   NaN                NaN                     NaN
# 1                   NaN                NaN                     NaN
# 2                   NaN                NaN                     NaN
# 3                   NaN                NaN                     NaN
# 4                   NaN                NaN                     NaN
#
#    bA3_DOWN_RIGHT_neighbor  bA3_BELOW_neighbor  bA3_ABOVE_neighbor  result
# 0                      NaN                 NaN                 NaN   Black
# 1                      NaN                 NaN                 NaN   Black
# 2                      NaN                 NaN                 NaN   Black
# 3                      NaN                 NaN                 NaN   Black
# 4                      NaN                 NaN                 NaN   Black
#
# [5 rows x 202 columns]

# %% [markdown]
# ## 2. Classifying the features

# %%
cols = list(df.columns)

moves_cols = [col for col in cols if 'moves' in col]
neighbor_cols = [col for col in cols if 'neighbor' in col]
color_player_cols = ['last_move_played_by', 'current_player_turn', 'result']

print(f'Columns ({len(moves_cols)}) containing the number of possible moves for each bug\n',moves_cols, '\n')
print(f'Columns ({len(neighbor_cols)}) containing the number of neighbors for each bug\n',neighbor_cols, '\n')
print(f'Columns ({len(color_player_cols)}) containing info described by White or Black\n',color_player_cols, '\n')
# Out:
# Columns (22) containing the number of possible moves for each bug
#  ['wQ_moves', 'wS1_moves', 'wB1_moves', 'wG1_moves', 'wA1_moves', 'wS2_moves', 'wB2_moves', 'wG2_moves', 'wA2_moves', 'wG3_moves', 'wA3_moves', 'bQ_moves', 'bS1_moves', 'bB1_moves', 'bG1_moves', 'bA1_moves', 'bS2_moves', 'bB2_moves', 'bG2_moves', 'bA2_moves', 'bG3_moves', 'bA3_moves']
#
# Columns (176) containing the number of neighbors for each bug
#  ['wQ_RIGHT_neighbor', 'wQ_UP_RIGHT_neighbor', 'wQ_UP_LEFT_neighbor', 'wQ_LEFT_neighbor', 'wQ_DOWN_LEFT_neighbor', 'wQ_DOWN_RIGHT_neighbor', 'wQ_BELOW_neighbor', 'wQ_ABOVE_neighbor', 'wS1_RIGHT_neighbor', 'wS1_UP_RIGHT_neighbor', 'wS1_UP_LEFT_neighbor', 'wS1_LEFT_neighbor', 'wS1_DOWN_LEFT_neighbor', 'wS1_DOWN_RIGHT_neighbor', 'wS1_BELOW_neighbor', 'wS1_ABOVE_neighbor', 'wB1_RIGHT_neighbor', 'wB1_UP_RIGHT_neighbor', 'wB1_UP_LEFT_neighbor', 'wB1_LEFT_neighbor', 'wB1_DOWN_LEFT_neighbor', 'wB1_DOWN_RIGHT_neighbor', 'wB1_BELOW_neighbor', 'wB1_ABOVE_neighbor', 'wG1_RIGHT_neighbor', 'wG1_UP_RIGHT_neighbor', 'wG1_UP_LEFT_neighbor', 'wG1_LEFT_neighbor', 'wG1_DOWN_LEFT_neighbor', 'wG1_DOWN_RIGHT_neighbor', 'wG1_BELOW_neighbor', 'wG1_ABOVE_neighbor', 'wA1_RIGHT_neighbor', 'wA1_UP_RIGHT_neighbor', 'wA1_UP_LEFT_neighbor', 'wA1_LEFT_neighbor', 'wA1_DOWN_LEFT_neighbor', 'wA1_DOWN_RIGHT_neighbor', 'wA1_BELOW_neighbor', 'wA1_ABOVE_neighbor', 'wS2_RIGHT_neighbor', 'wS2_UP_RIGHT_neighbor', 'wS2_UP_LEFT_neighbor', 'wS2_LEFT_neighbor', 'wS2_DOWN_LEFT_neighbor', 'wS2_DOWN_RIGHT_neighbor', 'wS2_BELOW_neighbor', 'wS2_ABOVE_neighbor', 'wB2_RIGHT_neighbor', 'wB2_UP_RIGHT_neighbor', 'wB2_UP_LEFT_neighbor', 'wB2_LEFT_neighbor', 'wB2_DOWN_LEFT_neighbor', 'wB2_DOWN_RIGHT_neighbor', 'wB2_BELOW_neighbor', 'wB2_ABOVE_neighbor', 'wG2_RIGHT_neighbor', 'wG2_UP_RIGHT_neighbor', 'wG2_UP_LEFT_neighbor', 'wG2_LEFT_neighbor', 'wG2_DOWN_LEFT_neighbor', 'wG2_DOWN_RIGHT_neighbor', 'wG2_BELOW_neighbor', 'wG2_ABOVE_neighbor', 'wA2_RIGHT_neighbor', 'wA2_UP_RIGHT_neighbor', 'wA2_UP_LEFT_neighbor', 'wA2_LEFT_neighbor', 'wA2_DOWN_LEFT_neighbor', 'wA2_DOWN_RIGHT_neighbor', 'wA2_BELOW_neighbor', 'wA2_ABOVE_neighbor', 'wG3_RIGHT_neighbor', 'wG3_UP_RIGHT_neighbor', 'wG3_UP_LEFT_neighbor', 'wG3_LEFT_neighbor', 'wG3_DOWN_LEFT_neighbor', 'wG3_DOWN_RIGHT_neighbor', 'wG3_BELOW_neighbor', 'wG3_ABOVE_neighbor', 'wA3_RIGHT_neighbor', 'wA3_UP_RIGHT_neighbor', 'wA3_UP_LEFT_neighbor', 'wA3_LEFT_neighbor', 'wA3_DOWN_LEFT_neighbor', 'wA3_DOWN_RIGHT_neighbor', 'wA3_BELOW_neighbor', 'wA3_ABOVE_neighbor', 'bQ_RIGHT_neighbor', 'bQ_UP_RIGHT_neighbor', 'bQ_UP_LEFT_neighbor', 'bQ_LEFT_neighbor', 'bQ_DOWN_LEFT_neighbor', 'bQ_DOWN_RIGHT_neighbor', 'bQ_BELOW_neighbor', 'bQ_ABOVE_neighbor', 'bS1_RIGHT_neighbor', 'bS1_UP_RIGHT_neighbor', 'bS1_UP_LEFT_neighbor', 'bS1_LEFT_neighbor', 'bS1_DOWN_LEFT_neighbor', 'bS1_DOWN_RIGHT_neighbor', 'bS1_BELOW_neighbor', 'bS1_ABOVE_neighbor', 'bB1_RIGHT_neighbor', 'bB1_UP_RIGHT_neighbor', 'bB1_UP_LEFT_neighbor', 'bB1_LEFT_neighbor', 'bB1_DOWN_LEFT_neighbor', 'bB1_DOWN_RIGHT_neighbor', 'bB1_BELOW_neighbor', 'bB1_ABOVE_neighbor', 'bG1_RIGHT_neighbor', 'bG1_UP_RIGHT_neighbor', 'bG1_UP_LEFT_neighbor', 'bG1_LEFT_neighbor', 'bG1_DOWN_LEFT_neighbor', 'bG1_DOWN_RIGHT_neighbor', 'bG1_BELOW_neighbor', 'bG1_ABOVE_neighbor', 'bA1_RIGHT_neighbor', 'bA1_UP_RIGHT_neighbor', 'bA1_UP_LEFT_neighbor', 'bA1_LEFT_neighbor', 'bA1_DOWN_LEFT_neighbor', 'bA1_DOWN_RIGHT_neighbor', 'bA1_BELOW_neighbor', 'bA1_ABOVE_neighbor', 'bS2_RIGHT_neighbor', 'bS2_UP_RIGHT_neighbor', 'bS2_UP_LEFT_neighbor', 'bS2_LEFT_neighbor', 'bS2_DOWN_LEFT_neighbor', 'bS2_DOWN_RIGHT_neighbor', 'bS2_BELOW_neighbor', 'bS2_ABOVE_neighbor', 'bB2_RIGHT_neighbor', 'bB2_UP_RIGHT_neighbor', 'bB2_UP_LEFT_neighbor', 'bB2_LEFT_neighbor', 'bB2_DOWN_LEFT_neighbor', 'bB2_DOWN_RIGHT_neighbor', 'bB2_BELOW_neighbor', 'bB2_ABOVE_neighbor', 'bG2_RIGHT_neighbor', 'bG2_UP_RIGHT_neighbor', 'bG2_UP_LEFT_neighbor', 'bG2_LEFT_neighbor', 'bG2_DOWN_LEFT_neighbor', 'bG2_DOWN_RIGHT_neighbor', 'bG2_BELOW_neighbor', 'bG2_ABOVE_neighbor', 'bA2_RIGHT_neighbor', 'bA2_UP_RIGHT_neighbor', 'bA2_UP_LEFT_neighbor', 'bA2_LEFT_neighbor', 'bA2_DOWN_LEFT_neighbor', 'bA2_DOWN_RIGHT_neighbor', 'bA2_BELOW_neighbor', 'bA2_ABOVE_neighbor', 'bG3_RIGHT_neighbor', 'bG3_UP_RIGHT_neighbor', 'bG3_UP_LEFT_neighbor', 'bG3_LEFT_neighbor', 'bG3_DOWN_LEFT_neighbor', 'bG3_DOWN_RIGHT_neighbor', 'bG3_BELOW_neighbor', 'bG3_ABOVE_neighbor', 'bA3_RIGHT_neighbor', 'bA3_UP_RIGHT_neighbor' ...
#
# Columns (3) containing info described by White or Black
#  ['last_move_played_by', 'current_player_turn', 'result']

# %%
df.describe()
# Out:
#        number_of_turn     wQ_moves    wS1_moves    wB1_moves    wG1_moves  \
# count     8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean      4332.000000     1.962830     1.862172     4.588826     2.407249
# std       2500.937024     0.938666     0.958588     1.054364     0.825955
# min          1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2166.500000     2.000000     2.000000     4.000000     2.000000
# 50%       4332.000000     2.000000     2.000000     4.000000     2.000000
# 75%       6497.500000     2.000000     2.000000     6.000000     3.000000
# max       8663.000000     4.000000     6.000000     6.000000     5.000000
#
#          wA1_moves    wS2_moves    wB2_moves    wG2_moves    wA2_moves  ...  \
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000  ...
# mean     34.383008     2.025626     4.733926     2.528685    31.927854  ...
# std      10.982707     1.102374     1.092136     0.802086    13.842177  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      35.000000     2.000000     4.000000     2.000000    33.000000  ...
# 50%      37.000000     2.000000     5.000000     3.000000    37.000000  ...
# 75%      40.000000     2.000000     6.000000     3.000000    40.000000  ...
# max      48.000000     6.000000     6.000000     5.000000    47.000000  ...
#
#          bS1_moves    bB1_moves    bG1_moves    bA1_moves    bS2_moves  \
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean      1.827658     4.581438     2.435761    33.935819     1.927854
# std       1.081086     1.024537     0.864792    11.656281     1.003682
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     4.000000     2.000000    34.000000     2.000000
# 50%       2.000000     5.000000     2.000000    37.000000     2.000000
# 75%       2.000000     5.000000     3.000000    40.000000     2.000000
# max       6.000000     6.000000     6.000000    47.000000     6.000000
#
#          bB2_moves    bG2_moves    bA2_moves    bG3_moves    bA3_moves
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean      4.656816     2.389703    32.836546     2.428027    32.930971
# std       1.086998     0.929789    12.992008     0.884124    13.160075
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     2.000000    34.000000     2.000000    34.000000
# 50%       5.000000     2.000000    37.000000     2.000000    37.000000
# 75%       6.000000     3.000000    40.000000     3.000000    40.000000
# max       6.000000     6.000000    48.000000     6.000000    47.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## 3. Replacing NaN values

# %%
# Replace the NaN values with 0
df.fillna(0, inplace=True)

# %% [markdown]
# ## 4. Scaling 'number_of_turn'

# %% [markdown]
# It's more useful to have an indicator of in which phase of the match the board state is (start, mid, end), and not the exact number of the turn.

# %%
# Use a MinMaxScaler to scale number_of_turn 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['number_of_turn'] = scaler.fit_transform(df[['number_of_turn']])
df.describe()
# Out:
#        number_of_turn     wQ_moves    wS1_moves    wB1_moves    wG1_moves  \
# count     8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean         0.500000     1.962830     1.862172     4.588826     2.407249
# std          0.288725     0.938666     0.958588     1.054364     0.825955
# min          0.000000     0.000000     0.000000     0.000000     0.000000
# 25%          0.250000     2.000000     2.000000     4.000000     2.000000
# 50%          0.500000     2.000000     2.000000     4.000000     2.000000
# 75%          0.750000     2.000000     2.000000     6.000000     3.000000
# max          1.000000     4.000000     6.000000     6.000000     5.000000
#
#          wA1_moves    wS2_moves    wB2_moves    wG2_moves    wA2_moves  ...  \
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000  ...
# mean     34.383008     2.025626     4.733926     2.528685    31.927854  ...
# std      10.982707     1.102374     1.092136     0.802086    13.842177  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      35.000000     2.000000     4.000000     2.000000    33.000000  ...
# 50%      37.000000     2.000000     5.000000     3.000000    37.000000  ...
# 75%      40.000000     2.000000     6.000000     3.000000    40.000000  ...
# max      48.000000     6.000000     6.000000     5.000000    47.000000  ...
#
#          bS1_moves    bB1_moves    bG1_moves    bA1_moves    bS2_moves  \
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean      1.827658     4.581438     2.435761    33.935819     1.927854
# std       1.081086     1.024537     0.864792    11.656281     1.003682
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     4.000000     2.000000    34.000000     2.000000
# 50%       2.000000     5.000000     2.000000    37.000000     2.000000
# 75%       2.000000     5.000000     3.000000    40.000000     2.000000
# max       6.000000     6.000000     6.000000    47.000000     6.000000
#
#          bB2_moves    bG2_moves    bA2_moves    bG3_moves    bA3_moves
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean      4.656816     2.389703    32.836546     2.428027    32.930971
# std       1.086998     0.929789    12.992008     0.884124    13.160075
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       4.000000     2.000000    34.000000     2.000000    34.000000
# 50%       5.000000     2.000000    37.000000     2.000000    37.000000
# 75%       6.000000     3.000000    40.000000     3.000000    40.000000
# max       6.000000     6.000000    48.000000     6.000000    47.000000
#
# [8 rows x 23 columns]

# %% [markdown]
# ## 5. Encoding neighbor columns

# %%
# Create a dictionary to encode all the possible pieces in the game
pieces_dict = {
    #white pieces
    'wQ': 1,
    'wA1': 2, 'wA2': 2, 'wA3': 2, 
    'wG1': 3, 'wG2': 3, 'wG3': 3,
    'wB1': 4, 'wB2': 4, 
    'wS1': 5, 'wS2': 5,
    'wM': 6,
    'wL': 7,
    'wP': 8,
    #black pieces
    'bQ': -1,
    'bA1': -2, 'bA2': -2, 'bA3': -2,
    'bG1': -3, 'bG2': -3, 'bG3': -3,
    'bB1': -4, 'bB2': -4,
    'bS1': -5, 'bS2': -5,
    'bM': -6,
    'bL': -7,
    'bP': -8
}

# %%
# for all the neighbors columns, replace the pieces with the corresponding values in the dictionary
for col in neighbor_cols:
    df[col] = df[col].replace(pieces_dict)

df.describe()
# Out:
#        number_of_turn     wQ_moves    wS1_moves    wB1_moves    wG1_moves  \
# count     8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean         0.500000     1.962830     1.862172     4.588826     2.407249
# std          0.288725     0.938666     0.958588     1.054364     0.825955
# min          0.000000     0.000000     0.000000     0.000000     0.000000
# 25%          0.250000     2.000000     2.000000     4.000000     2.000000
# 50%          0.500000     2.000000     2.000000     4.000000     2.000000
# 75%          0.750000     2.000000     2.000000     6.000000     3.000000
# max          1.000000     4.000000     6.000000     6.000000     5.000000
#
#          wA1_moves    wS2_moves    wB2_moves    wG2_moves    wA2_moves  ...  \
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000  ...
# mean     34.383008     2.025626     4.733926     2.528685    31.927854  ...
# std      10.982707     1.102374     1.092136     0.802086    13.842177  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%      35.000000     2.000000     4.000000     2.000000    33.000000  ...
# 50%      37.000000     2.000000     5.000000     3.000000    37.000000  ...
# 75%      40.000000     2.000000     6.000000     3.000000    40.000000  ...
# max      48.000000     6.000000     6.000000     5.000000    47.000000  ...
#
#        bG3_BELOW_neighbor  bG3_ABOVE_neighbor  bA3_RIGHT_neighbor  \
# count         8663.000000         8663.000000         8663.000000
# mean            -2.898072           -2.898072            0.138058
# std              0.847600            0.847600            2.276867
# min             -4.000000           -4.000000           -5.000000
# 25%             -3.000000           -3.000000            0.000000
# 50%             -3.000000           -3.000000            0.000000
# 75%             -3.000000           -3.000000            0.000000
# max              4.000000            4.000000            5.000000
#
#        bA3_UP_RIGHT_neighbor  bA3_UP_LEFT_neighbor  bA3_LEFT_neighbor  \
# count            8663.000000           8663.000000        8663.000000
# mean                0.104121             -0.195544           0.138058
# std                 1.770029              2.310436           2.276867
# min                -5.000000             -5.000000          -5.000000
# 25%                 0.000000              0.000000           0.000000
# 50%                 0.000000              0.000000           0.000000
# 75%                 0.000000              0.000000           0.000000
# max                 5.000000              5.000000           5.000000
#
#        bA3_DOWN_LEFT_neighbor  bA3_DOWN_RIGHT_neighbor  bA3_BELOW_neighbor  \
# count             8663.000000              8663.000000         8663.000000
# mean                 0.104121                -0.195544           -1.859402
# std                  1.770029                 2.310436            0.977745
# min                 -5.000000                -5.000000           -4.000000
# 25%                  0.000000                 0.000000           -2.000000
# 50%                  0.000000                 0.000000           -2.000000
# 75%                  0.000000                 0.000000           -2.000000
# max                  5.000000                 5.000000            4.000000
#
#        bA3_ABOVE_neighbor
# count         8663.000000
# mean            -1.859402
# std              0.977745
# min             -4.000000
# 25%             -2.000000
# 50%             -2.000000
# 75%             -2.000000
# max              4.000000
#
# [8 rows x 199 columns]

# %% [markdown]
# ## 6. Encoding color_player columns

# %%
color_player_dict = {
    'White': 1,
    'Black': -1
}

# %%
# Replace all the color_player columns with the corresponding values in the dictionary
for col in color_player_cols:
    df[col] = df[col].replace(color_player_dict)

df.describe()
# Out:
#        number_of_turn  last_move_played_by  current_player_turn     wQ_moves  \
# count     8663.000000          8663.000000          8663.000000  8663.000000
# mean         0.500000             0.000115            -0.000115     1.962830
# std          0.288725             1.000058             1.000058     0.938666
# min          0.000000            -1.000000            -1.000000     0.000000
# 25%          0.250000            -1.000000            -1.000000     2.000000
# 50%          0.500000             1.000000            -1.000000     2.000000
# 75%          0.750000             1.000000             1.000000     2.000000
# max          1.000000             1.000000             1.000000     4.000000
#
#          wS1_moves    wB1_moves    wG1_moves    wA1_moves    wS2_moves  \
# count  8663.000000  8663.000000  8663.000000  8663.000000  8663.000000
# mean      1.862172     4.588826     2.407249    34.383008     2.025626
# std       0.958588     1.054364     0.825955    10.982707     1.102374
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     4.000000     2.000000    35.000000     2.000000
# 50%       2.000000     4.000000     2.000000    37.000000     2.000000
# 75%       2.000000     6.000000     3.000000    40.000000     2.000000
# max       6.000000     6.000000     5.000000    48.000000     6.000000
#
#          wB2_moves  ...  bG3_ABOVE_neighbor  bA3_RIGHT_neighbor  \
# count  8663.000000  ...         8663.000000         8663.000000
# mean      4.733926  ...           -2.898072            0.138058
# std       1.092136  ...            0.847600            2.276867
# min       0.000000  ...           -4.000000           -5.000000
# 25%       4.000000  ...           -3.000000            0.000000
# 50%       5.000000  ...           -3.000000            0.000000
# 75%       6.000000  ...           -3.000000            0.000000
# max       6.000000  ...            4.000000            5.000000
#
#        bA3_UP_RIGHT_neighbor  bA3_UP_LEFT_neighbor  bA3_LEFT_neighbor  \
# count            8663.000000           8663.000000        8663.000000
# mean                0.104121             -0.195544           0.138058
# std                 1.770029              2.310436           2.276867
# min                -5.000000             -5.000000          -5.000000
# 25%                 0.000000              0.000000           0.000000
# 50%                 0.000000              0.000000           0.000000
# 75%                 0.000000              0.000000           0.000000
# max                 5.000000              5.000000           5.000000
#
#        bA3_DOWN_LEFT_neighbor  bA3_DOWN_RIGHT_neighbor  bA3_BELOW_neighbor  \
# count             8663.000000              8663.000000         8663.000000
# mean                 0.104121                -0.195544           -1.859402
# std                  1.770029                 2.310436            0.977745
# min                 -5.000000                -5.000000           -4.000000
# 25%                  0.000000                 0.000000           -2.000000
# 50%                  0.000000                 0.000000           -2.000000
# 75%                  0.000000                 0.000000           -2.000000
# max                  5.000000                 5.000000            4.000000
#
#        bA3_ABOVE_neighbor  result
# count         8663.000000  8663.0
# mean            -1.859402    -1.0
# std              0.977745     0.0
# min             -4.000000    -1.0
# 25%             -2.000000    -1.0
# 50%             -2.000000    -1.0
# 75%             -2.000000    -1.0
# max              4.000000    -1.0
#
# [8 rows x 202 columns]
